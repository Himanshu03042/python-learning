# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu03042/python-learning/blob/main/Day05_Tuples_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 5 - Tuples & Sets in Python
#
# ## Topics Covered
# - What is a Tuple?
# - Creating a Tuple
# - Tuple Indexing
# - Tuple Slicing
# - Tuple Methods
# - What is a Set?
# - Creating a Set
# - Set Methods
# - Difference between List, Tuple and Set
#
# ## Objective
# Learn how Tuples and Sets work and understand when to use them.
#
# Author: Himanshu
# Date: 24 August 2026

# %%
#TUPLE

# num =(10,20,30,40,50,20)
# print(num[0],num[-1],num.count(20),num.index(40))
# print(num[1:5])
# num[0]=100
# | Data Structure | Brackets | Duplicate     |
# | -------------- | -------- | ------------- |
# | List           | `[]`     | ✅ Allowed     |
# | Tuple          | `()`     | ✅ Allowed     |
# | Set            | `{}`     | ❌ Not allowed |

# SET
nums={10,20,30,20,6,10}
nums.add(50)
nums.remove(20)
print(30 in nums,100 in nums)
print(nums)
# print(sorted(nums))
fruits ={"appple","mango", "banana","apple","mango"}
print(len(fruits))
print(fruits)
#UNION AND INTERSECTION AND DIFFERENCE
a={1,2,3,4,5,6}
b={4,5,6,7,8,9}
print(a.union(b))
print(a.intersection(b))
print(a.difference(b))
# print(a.symmertric_difference(b))

# MINI PROJECT
pystd={"aman","rohit","himanshu","rahul"}
mlstd={"himanshu","rahul","karan","vikas"}
print("common students:- ",pystd.intersection(mlstd))
print("python only students",pystd.difference(mlstd))
print("ml only students",mlstd.difference(pystd))
print("all students",pystd.union(mlstd))
print(pystd.union(mlstd))
print(len(pystd.union(mlstd)))
# Out:
# True False
# {6, 10, 50, 30}
# 4
# {'apple', 'mango', 'banana', 'appple'}
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {1, 2, 3}
# common students:-  {'himanshu', 'rahul'}
# python only students {'rohit', 'aman'}
# ml only students {'karan', 'vikas'}
# all students {'rohit', 'rahul', 'himanshu', 'vikas', 'karan', 'aman'}
# {'rohit', 'rahul', 'himanshu', 'vikas', 'karan', 'aman'}
# 6
