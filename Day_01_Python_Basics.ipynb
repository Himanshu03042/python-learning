# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu03042/python-learning/blob/main/Day_01_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print("helli,python")
# name=input("enter your name")
# college=input("enter your college name")
# branch=input("enter your branch name")
# semester=input("enter your semester")
# print("name",name)
# print("college",college)
# print("branch",branch)
# print("semester",semester)
# name,college,branch,semester=input("enter your name,college,branch,semester:").split(",")
# name,college,branch,semester=[input(f"enter your{item}:")for item in["name","college","branch","semester"]]
# print(name,college,branch,semester)
# student={"name":input("enter your name"),
#          "college":input("enter your college"),
#          "branch":input("enter your branch"),
#          "semester":input("enter your branch")
#          }
# print(student)
# r=float(input("enter the raddius of circle"))

# areaofcircle=22/7*r*r
# print("areaofcircle is:",areaofcircle)
# averageoffivenumbers=int(input(n1,n2,n3,n4,n5))/5
# print(averageoffivenumbers)
# n1=int(input("enter the first number"))
# n2=int(input("enter the second number"))
# n3=int(input("enter the third number"))
# n4=int(input("enter the fourth number"))
# n5=int(input("enter the fifth number"))
# average=(n1+n2+n3+n4+n5)/5
# print("average is",average)
# n1,n2,n3,n4,n5=map(int,input("enter five numbers seperated by space").split())
# average=(n1+n2+n3+n4+n5)/5
# print("average is ",average)
# numbers=[]
# for i in range(5):
#   num=int(input(f"enter number{i+1}:"))
#   numbers.append(num)
# average=sum(numbers)/len(numbers)
# print("average is",average)
# num=int(input("enter the number"))
# if num%2==0:
#   print("number is even")
# else:
#    ("the number is odd")
# phy=int(input("enter the phy marks"))
# chem=int(input("enter the chem marks"))
# math=int(input("enter the math marks"))
# total=phy+chem+math
# percentage=(total/300)*100
# print("percentage is ",percentage)
# print("total marks is",total)
# if phy <33 or chem<33 or math<33:
#   print("student is fial")

#   if phy<33:
#     print("fail in phy")
#   if chem<33:
#     print("fail in chem")
#   if math<33:
#     print("fail in math")
# else:
#   if percentage >=90:
#     print("grade is A")
#   if percentage >=90:
#     print("grade is A")
#   elif percentage >=80 and percentage<90:
#     print("grade is B")
#   elif percentage >=70 and percentage<80:
#     print("grade is C")
#   elif percentage >=60 and percentage<70:
#     print("grade is D")
#   else:
#     print("grade is FFFFF")
# Out:
# enter the phy marks89
# enter the chem marks33
# enter the math marks44
# percentage is  55.333333333333336
# total marks is 166
# grade is FFFFF
