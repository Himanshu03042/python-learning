# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu03042/python-learning/blob/main/Day03_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 3 - Strings in Python
#
# ## Topics Covered
# - What is a String?
# - String Creation
# - String Indexing
# - Positive Indexing
# - Negative Indexing
# - len() Function
# - Practice Questions
#
# ## Objective
# Learn how to create strings, access characters using indexing, and find the length of a string.
#
# Author: Himanshu
# Date: 01 August 2026

# %%
word="Apple"
print(word[0])
word[-1]
len(word)
# Out:
# A
# 5

# %%
name ="programming"
print(name[0])
print(name[-1])
len(name)
# Out:
# p
# g
# 11

# %%
city="mumbai"
print(city[0])
print(city[3])
print(city[5])
print(city[-6])
print(city[-3])
print(city[-1])
# Out:
# m
# b
# i
# m
# b
# i

# %%
name = "machine learning"
print(name.upper())
print(name.capitalize())
print(name.title())
course = "Python Programming"
print(course.replace("python","java"))
text = "Data Science"
print(text.startswith("Data"))
print(text.endswith("science"))

word = "Mississippi"
print(word.count("s"),word.count("i"))
name="    him  ans  hu     "
print(name.strip(),name.lstrip(),name.rstrip(),name.strip())
# Out:
# MACHINE LEARNING
# Machine learning
# Machine Learning
# Python Programming
# True
# False
# 4 4
# him  ans  hu him  ans  hu          him  ans  hu him  ans  hu

# %%
word ='python'
print(word.startswith("py"))
print(word.endswith("on"))
name="himanshu"
print(name.startswith("hi"))
print(name.endswith("shu"))
# Out:
# True
# True
# True
# True

# %%
#strip
name="  Himanshu"
print(name.strip( ).upper())
# Out:
# HIMANSHU

# %%
#QUESTIONS
# text = "    python programming     "
# print(text.strip().upper())
# word = "mississippiee"
# print(len(word),word.upper(),word.count("s"))
name ="    himanshu     "
print(name.strip().upper(),len(name),name.startswith(""), name.endswith("hu"))
print(len(name))
print(name.strip().startswith("hi"))
print(name.strip().endswith("shu"))
# Out:
# HIMANSHU 17 True False
# 17
# True
# True

# %%
#FINAL DAY 3 PRACTICE
# name =input("enter your name:- ").strip().upper()
# print(name,len(name),"python" in name)

word = "Mississippi"
print(len(word),word.count("s"),word.count("i"),word[0],word[-1])
# Out:
# 11 4 4 M i
